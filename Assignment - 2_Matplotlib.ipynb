# %%
import pandas as pd
re=pd.read_csv("data1.csv")

# %%
re.tail()
# Out:
#     Unnamed: 0                                    Headphone Names  Price  \
# 35          35                boAt Rockerz 255F Bluetooth Headset    899
# 36          36  boAt Rockerz 510 Super Extra Bass Bluetooth He...    999
# 37          37  boAt Rockerz 255F Pro with Fast Charging Bluet...    949
# 38          38  TEQIR TR- 51 Wireless Neckband with 36 Hours P...    598
# 39          39                boAt Airdopes 402 Bluetooth Headset  1,399
#
#     Rating
# 35     4.4
# 36     4.1
# 37     4.4
# 38     3.9
# 39     4.3

# %%
re.head()
# Out:
#    Unnamed: 0                                    Headphone Names  Price  \
# 0           0  boAt Airdopes 131 with upto 15 Hours Playback,...    949
# 1           1  boAt Rockerz 235v2/238 with ASAP Charge and up...    849
# 2           2  boAt Airdopes 131 with upto 15 Hours Playback,...    949
# 3           3               boAt Rockerz 205v2 Bluetooth Headset  1,149
# 4           4  boAt Rockerz 255F Pro with ASAP Charge and upt...    949
#
#    Rating
# 0     4.1
# 1     4.2
# 2     4.1
# 3     4.1
# 4     4.2

# %%
re.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       40 non-null     int64
#  1   Headphone Names  40 non-null     object
#  2   Price            40 non-null     object
#  3   Rating           40 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.4+ KB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.bar(re["Price"],re["Headphone Names"],width = 0.5)
plt.rcParams["figure.figsize"] = (4, 8)
plt.figure(figsize=(18,15))
plt.show()

# %%
plt.bar(re["Rating"],re["Headphone Names"],width = 0.3)
plt.figure(figsize=(18,15))
plt.show()
